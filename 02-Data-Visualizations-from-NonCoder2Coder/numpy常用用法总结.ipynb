# %%
import numpy as np

# %%
array = np.array([[1,2,3], [2,3,4]])

# %%
print(array)
print(array.dtype)
print(array.ndim)
print(array.shape)
print(array.size)
# Out:
# [[1 2 3]
#  [2 3 4]]
# int64
# 2
# (2, 3)
# 6

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.scatter(x, y)
